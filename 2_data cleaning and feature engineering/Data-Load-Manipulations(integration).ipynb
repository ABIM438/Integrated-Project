# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

insurance_df = pd.read_excel('C:/github/Integration_Project/datasets/insurance_claims_raw.xlsx')
insurance_df.head()
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
missing_values = insurance_df.isnull().sum()
print(missing_values)
# Out:
# months_as_customer                0
# age                               2
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 2
# policy_annual_premium             3
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           1
# insured_occupation                0
# insured_hobbies                   2
# insured_relationship              0
# capital-gains                     2
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            93
# incident_state                    2
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
numeric_means = insurance_df.select_dtypes(include=[np.number]).mean()
insurance_df_filled = insurance_df.fillna(numeric_means)
categorical_mode = insurance_df.select_dtypes(include=[object]).mode().iloc[0]
insurance_df_filled.update(insurance_df.select_dtypes(include=[object]).fillna(categorical_mode))

# %%
missing_values_new = insurance_df_filled.isnull().sum()
print(missing_values_new)
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %%
insurance_df_filled.drop(columns=["_c39"], inplace=True)

# %%
insurance_df_filled.to_excel('C:/github/Integration_Project/datasets/insurance_claims_processed.xlsx', index=False)
